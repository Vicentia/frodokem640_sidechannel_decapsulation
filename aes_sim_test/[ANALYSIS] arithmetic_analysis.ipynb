# %% [markdown]
# # Arithmetic Visualization

# %%
from pathlib import Path
import os
import re

import numpy as np
import pandas as pd

from HW_HD_utils import *
from plots_utils import *

# %%
selected_registers = ["r0", "r1", "r2", "r3", "r4", "r5", "r6", "r7", "r8", "r9", "r10", "r11", "r12", "sp", "lr"]
csv_path = "output_decapsulation_sample/trace_0_0.csv"
result_dir_arithmetic = "Results_arithmetic"
no_instructions = 500

reset_result_dir = False
if reset_result_dir:
    reset_folder(result_dir_arithmetic)
os.makedirs(result_dir_arithmetic, exist_ok=True)

df_full, hw_trace, hd_trace = plot_trace_with_arithmetic(csv_path, selected_registers, result_dir_arithmetic, no_instructions)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       8     reset_folder(result_dir_arithmetic)
#       9 os.makedirs(result_dir_arithmetic, exist_ok=True)
# ---> 11 df_full, hw_trace, hd_trace = plot_trace_with_arithmetic(csv_path, selected_registers, result_dir_arithmetic, no_instructions)
#
# TypeError: plot_trace_with_arithmetic() takes from 2 to 3 positional arguments but 4 were given
