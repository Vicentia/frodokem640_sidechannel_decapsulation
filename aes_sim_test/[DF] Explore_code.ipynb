# %% [markdown]
# # Prologue

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
import pandas as pd
import csv
import re
import codecs
import importlib
import sys, os
sys.path.append(os.getcwd())
from DF_util import *

# %%
def add_comment(pattern, position_file,instructions_list, comment):
    positions_list= load_list(position_file)
    ranges = []
    for pos in positions_list:
        ranges.extend(range(pos, pos + len(pattern)))
    for j in range(len(positions_list)):
        start_pos=positions_list[j]
        for j in range(len(pattern)):
            instructions_list[start_pos + j]= comment
    return instructions_list

# %% [markdown]
# # Create pretty execution trace
# To be done only to be  once
# 1. remove the .w from instructions names
# 2. add comments about where the gadgets are

# %%
TRACE=0
filename='frodo_traces/trace_'+str(TRACE)
df_trace=pd.read_csv(filename+'.csv')

# %%
df_trace.head()
# Out:
#           pc  bytecode instruction         operands          r0          r1  \
# 0  0x8001ef4      7047          bx               lr  0x40020000      0x1000
# 1  0x8000d7e      084a         ldr  r2, [pc, #0x20]  0x40020000      0x1000
# 2  0x8000d80      0849         ldr  r1, [pc, #0x20]  0x40020000      0x1000
# 3  0x8000d82      601c        adds       r0, r4, #1  0x40020000  0x20000019
# 4  0x8000d84  00f0f2f8          bl       #0x8000f6c  0x20000009  0x20000019
#
#            r2   r3          r4          r5    r6          r7          r8   r9  \
# 0         0x1  0x1  0x20000008  0x20007404  0x40  0x2001ff60  0x20007404  0x0
# 1         0x1  0x1  0x20000008  0x20007404  0x40  0x2001ff60  0x20007404  0x0
# 2  0x20002611  0x1  0x20000008  0x20007404  0x40  0x2001ff60  0x20007404  0x0
# 3  0x20002611  0x1  0x20000008  0x20007404  0x40  0x2001ff60  0x20007404  0x0
# 4  0x20002611  0x1  0x20000008  0x20007404  0x40  0x2001ff60  0x20007404  0x0
#
#    r10  r11   r12          sp         lr       pc.1
# 0  0x0  0x0  0x14  0x2001ff00  0x8000d7f  0x8001ef4
# 1  0x0  0x0  0x14  0x2001ff00  0x8000d7f  0x8000d7e
# 2  0x0  0x0  0x14  0x2001ff00  0x8000d7f  0x8000d80
# 3  0x0  0x0  0x14  0x2001ff00  0x8000d7f  0x8000d82
# 4  0x0  0x0  0x14  0x2001ff00  0x8000d7f  0x8000d84

# %%
print(f"The length of the trace until now is: {len(df_trace)}")
print_code(df_trace,300000, 20, registers=['pc', 'instruction', 'operands'])
# Out:
# The length of the trace until now is: 300898
#                pc instruction            operands
# 300000  0x80014ce         ldr            r3, [sp]
# 300001  0x80014d0        movs              r4, #0
# 300002  0x80014d2       add.w  sl, r3, ip, lsl #1
# 300003  0x80014d6           b          #0x8001530
# 300004  0x8001530         cmp              r4, r6
# 300005  0x8001532         blo          #0x80014d8
# 300006  0x80014d8        subs          r0, r6, r4
# 300007  0x80014da         cmp              r2, r0
# 300008  0x80014dc         mov              r3, r2
# 300009  0x80014de       mov.w              r1, #1
# 300010  0x80014e2          it                  ge
# 300011  0x80014e6        lsls              r1, r3
# 300012  0x80014e8       sub.w          sb, r2, r3
# 300013  0x80014ec        subs              r1, #1
# 300014  0x80014ee       asr.w          fp, lr, sb
# 300015  0x80014f2        uxth              r1, r1
# 300016  0x80014f4       and.w          fp, fp, r1
# 300017  0x80014f8      uxtb.w              fp, fp
# 300018  0x80014fc        subs          r0, r0, r3
# 300019  0x80014fe       lsl.w          r0, fp, r0

# %% [markdown]
# ## Add comments

# %%
def find_all_indices(lst, element):
    return [i for i, x in enumerate(lst) if x == element]
pc_list=df_trace['pc'].tolist()

# %% [markdown]
# This is the first unpack (the one that we care about because B'=unpack(c1))

# %%
PC_value='0x8001006'
indices = find_all_indices(pc_list, PC_value)
print(indices)
# Out:
# [43851]

# %% [markdown]
# Thi is the end of the first unpack

# %%
PC_value='0x800101e'
indices = find_all_indices(pc_list, PC_value)
print(indices)
# Out:
# [43858]

# %% [markdown]
# This is the beginning of the second one

# %%
PC_value='0x8001022'
indices = find_all_indices(pc_list, PC_value)
print(indices)
# Out:
# []

# %% [markdown]
# This is the end of the secon one

# %%
PC_value='0x800102e'
indices = find_all_indices(pc_list, PC_value)
print(indices)
# Out:
# []

# %% [markdown]
# This is the trigger_high()

# %%
PC_value='0x8001032'
indices = find_all_indices(pc_list, PC_value)
print(indices)
# Out:
# []

# %% [markdown]
# This is the start of the mult_bs

# %%
PC_value='0x8001036'
indices = find_all_indices(pc_list, PC_value)
print(indices)
# Out:
# []

# %% [markdown]
# This is the end of multiplication

# %%
PC_value='0x8001044'
indices = find_all_indices(pc_list, PC_value)
index_mult = indices[0] if indices else None
print(f"The index of the multiplication is: {index_mult}")
print(indices)
# Out:
# []

# %% [markdown]
# In the case in which the multiplication was foud, then print the registers:

# %%
print_code(df_trace, index_mult, 1, registers=['pc','instruction','operands','r0', 'r1','r2'])
